# %% [markdown]
# Import necessary libraries

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# DATASET

# %%
# Define the XOR input and output data
#4 samples each with 2 features
X = np.array([[0,0], [0,1], [1,0], [1,1]]) #same input gives 0 different gives 1
y = np.array([[0], [1], [1], [0]]) #labels

# %% [markdown]
# Build the neural network model

# %%
model = Sequential()
#model.add(Dense(2, input_dim=2, activation='relu'))  # Hidden layer with 2 neurons
model.add(Dense(2, input_dim=2, activation='tanh'))
model.add(Dense(1, activation='sigmoid'))            # Output layer with 1 neuron

# %%
# Compile the model
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Train the model
model.fit(X, y, epochs = 3000, verbose = 1)

# Evaluate the model
_, accuracy = model.evaluate(X, y)
print(f'Accuracy: {accuracy*100:.2f}%')

# Make predictions
predictions = model.predict(X)
predictions = np.round(predictions).astype(int)   # forward pass → convert probabilites to 0 or 1

print("Predictions: ")
for i in range(len(X)):
    print(f"Input: {X[i]} => Output: {predictions[i][0]}")
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
# Epoch 505/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7500 - loss: 0.6592
# Epoch 506/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7500 - loss: 0.6590
# Epoch 507/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7500 - loss: 0.6587
# Epoch 508/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7500 - loss: 0.6585
# Epoch 509/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7500 - loss: 0.6582
# Epoch 510/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7500 - loss: 0.6580
# Epoch 511/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7500 - loss: 0.6577
# Epoch 512/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7500 - loss: 0.6575
# Epoch 513/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7500 - loss: 0.6572
# Epoch 514/3000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7500 - loss: 0.6569
# Epoch 515/3000
# ...
